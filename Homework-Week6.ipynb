# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import io
import requests

from scipy.stats import norm

# %%
data_file = r"C:\Users\david\Documents\GitHub\E11_David_Julian_Matt\datainside.csv"
df4p = pd.read_csv(data_file)
mask = df4p["Time"] > 1677280869
df4 = df4p[mask]
display(df4)
# Out:
#              Time  PM 1.0  PM2.5  PM10  Temperature     Gas   Humidity  \
# 27   1.677281e+09       0      0     0    22.216328   90180  27.689746
# 28   1.677281e+09       0      0     0    22.221992   90735  27.658047
# 29   1.677281e+09       0      0     0    22.228242   91203  27.647820
# 30   1.677281e+09       0      0     0    22.233906   91866  27.632193
# 31   1.677281e+09       0      0     0    22.239961   91961  27.627307
# ..            ...     ...    ...   ...          ...     ...        ...
# 323  1.677281e+09       0      0     0    23.062031  115680  26.292801
# 324  1.677281e+09       0      0     0    23.059492  115454  26.255449
# 325  1.677281e+09       0      0     0    23.056172  115529  26.228663
# 326  1.677281e+09       0      0     0    23.054609  115756  26.202014
# 327  1.677281e+09       0      0     0    23.054023  115984  26.175443
#
#        Pressure    Altitude
# 27   996.299222  142.092396
# 28   996.296343  142.116700
# ...

# %%
pm1 = df4["PM 1.0"]
pm25 = df4["PM2.5"]
pm10 = df4["PM10"]
temperature = df4["Temperature"]
gas = df4["Gas"]
humidity = df4["Humidity"]
pressure = df4["Pressure"]
altitude = df4["Altitude"]

# %%
plt.hist(df4["PM 1.0"],bins=10)
plt.ylabel('Frequency')
plt.xlabel('PM 1.0')
plt.show()
"""
list1 = df4["PM 1.0"]
mu = np.mean(list1)
sigma = np.std(list1)
print("std: " + str(sigma))
x = np.linspace(mu - 5*sigma, mu + 5*sigma, 100)
y=norm.pdf(x, mu, sigma)
plt.plot(x,y, label="P(x)")
plt.show()
"""
# Out:
# '\nlist1 = df4["PM 1.0"]\nmu = np.mean(list1)\nsigma = np.std(list1)\nprint("std: " + str(sigma))\nx = np.linspace(mu - 5*sigma, mu + 5*sigma, 100)\ny=norm.pdf(x, mu, sigma)\nplt.plot(x,y, label="P(x)")\nplt.show()\n'

# %%
plt.hist(df4["PM2.5"],bins=10)
plt.ylabel('Frequency')
plt.xlabel('PM 2.5')
plt.show()
"""
list2 = df4["PM2.5"]
mu = np.mean(list2)
sigma = np.std(list2)
print("std: " + str(sigma))
x = np.linspace(mu - 5*sigma, mu + 5*sigma, 100)
y=norm.pdf(x, mu, sigma)
plt.plot(x,y, label="P(x)")
plt.show()
"""
# Out:
# '\nlist2 = df4["PM2.5"]\nmu = np.mean(list2)\nsigma = np.std(list2)\nprint("std: " + str(sigma))\nx = np.linspace(mu - 5*sigma, mu + 5*sigma, 100)\ny=norm.pdf(x, mu, sigma)\nplt.plot(x,y, label="P(x)")\nplt.show()\n'

# %%
plt.hist(df4["PM10"],bins=10)
plt.ylabel('Frequency')
plt.xlabel('PM 10')
plt.show()
"""
list3=df4["PM10"]
mu = np.mean(list3)
sigma = np.std(list3)
print("std: " + str(sigma))
x = np.linspace(mu - 5*sigma, mu + 5*sigma, 100)
y=norm.pdf(x, mu, sigma)
plt.plot(x,y, label="P(x)")
plt.show()
"""
# Out:
# '\nlist3=df4["PM10"]\nmu = np.mean(list3)\nsigma = np.std(list3)\nprint("std: " + str(sigma))\nx = np.linspace(mu - 5*sigma, mu + 5*sigma, 100)\ny=norm.pdf(x, mu, sigma)\nplt.plot(x,y, label="P(x)")\nplt.show()\n'

# %%
plt.hist(df4["Temperature"],bins=40)
plt.ylabel('Frequency')
plt.xlabel('Temperature')
plt.show()

"""
list4=df4["Temperature"]
mu = np.mean(list4)
sigma = np.std(list4)
print("std: " + str(sigma))
x = np.linspace(mu - 5*sigma, mu + 5*sigma, 100)
y=norm.pdf(x, mu, sigma)
plt.plot(x,y, label="P(x)")
plt.show()
"""
# Out:
# '\nlist4=df4["Temperature"]\nmu = np.mean(list4)\nsigma = np.std(list4)\nprint("std: " + str(sigma))\nx = np.linspace(mu - 5*sigma, mu + 5*sigma, 100)\ny=norm.pdf(x, mu, sigma)\nplt.plot(x,y, label="P(x)")\nplt.show()\n'

# %%
plt.hist(df4["Gas"],bins=30,density=True)
plt.ylabel('Frequency')
plt.xlabel('Gas')


list1 = df4["Gas"]
mu = np.mean(list1)
sigma = np.std(list1)
print("std: " + str(sigma))
x = np.linspace(mu - 5*sigma, mu + 5*sigma, 100)
y=norm.pdf(x, mu, sigma)
plt.plot(x,y, label="P(x)")

plt.show()
# Out:
# std: 5389.389380282054

# %%
plt.hist(df4["Humidity"],bins=20)
plt.ylabel('Frequency')
plt.xlabel('Humidity')
plt.show()

# %%
plt.hist(df4["Pressure"],bins=25)
plt.ylabel('Frequency')
plt.xlabel('Altitude')
plt.show()

# %%
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
# Out:
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################

# %%
data_file = r"C:\Users\david\Documents\GitHub\E11_David_Julian_Matt\dataoutside.csv"
df3p = pd.read_csv(data_file)
mask = df3p["Time"] > 1677280320.9
df3 = df3p[mask]
display(df3)
# Out:
#              Time  PM 1.0  PM2.5  PM10  Temperature     Gas   Humidity  \
# 136  1.677280e+09       2      2     2    18.626094   99536  30.664187
# 137  1.677280e+09       2      2     2    18.577461  100554  30.692852
# 138  1.677280e+09       2      2     2    18.526875  100898  30.737687
# 139  1.677280e+09       2      2     2    18.483516  101303  30.777680
# 140  1.677280e+09       2      2     2    18.438398  101652  30.790311
# ..            ...     ...    ...   ...          ...     ...        ...
# 432  1.677281e+09       2      3     3    22.160273  107982  27.685401
# 433  1.677281e+09       2      3     3    22.113984  109656  27.778252
# 434  1.677281e+09       2      3     3    22.072578  109520  27.828637
# 435  1.677281e+09       2      3     3    22.018086  109997  27.926286
# 436  1.677281e+09       2      3     3    21.962617  108846  28.056123
#
#        Pressure    Altitude
# 136  995.668809  147.414568
# 137  995.673746  147.372877
# ...

# %%
plt.hist(df3["PM 1.0"],bins=8)
plt.ylabel('Frequency')
plt.xlabel('PM 1.0')
plt.show()

# %%
plt.hist(df3["PM2.5"],bins=10)
plt.ylabel('Frequency')
plt.xlabel('PM 2.5')
# Out:
# Text(0.5, 0, 'PM 2.5')

# %%
plt.hist(df3["PM10"],bins=10)
plt.ylabel('Frequency')
plt.xlabel('PM 10')
# Out:
# Text(0.5, 0, 'PM 10')

# %%
plt.hist(df3["Temperature"],bins=35)
plt.ylabel('Frequency')
plt.xlabel('Temperature')
plt.show()

# %%
plt.hist(df3["Gas"],bins=30)
plt.ylabel('Frequency')
plt.xlabel('Gas')
plt.show()

# %%
plt.hist(df3["Humidity"],bins=20)
plt.ylabel('Frequency')
plt.xlabel('Humidity')
plt.show()

# %%
plt.hist(df3["Pressure"],bins=20)
plt.ylabel('Frequency')
plt.xlabel('Pressure')
plt.show()

# %%
plt.hist(df3["Altitude"],bins=20)
plt.ylabel('Frequency')
plt.xlabel('Altitude')
plt.show()

# %%
print("####################################################################################################################")
print("####################################################################################################################")
print("####################################################################################################################")
print("####################################################################################################################")
print("####################################################################################################################")
print("####################################################################################################################")
# Out:
# ####################################################################################################################
# ####################################################################################################################
# ####################################################################################################################
# ####################################################################################################################
# ####################################################################################################################
# ####################################################################################################################

# %%
plt.hist(df4["PM 1.0"],bins=8, label = "Indoor")
plt.hist(df3["PM 1.0"],bins=8, label = "Outdoor")
plt.ylabel('Frequency')
plt.xlabel('PM 1.0')
plt.legend()
plt.show()

m4 = np.mean(df4["PM 1.0"])
s4 = np.std(df4["PM 1.0"])
u4 = s4/300**(1/2)

m3 = np.mean(df3["PM 1.0"])
s3 = np.std(df3["PM 1.0"])
u3 = s3/300**(1/2)

print("Mean Indoor: " + str(m4) + "//STD Indoor: " + str(s4) + "//MeanU Indoor: " + str(u4) + "\nMean Outdoor: " + str(m3) + "//STD Outdoor: " + str(s3) + "//MeanU Outdoor: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Indoor: 0.059800664451827246//STD Indoor: 0.23711715455223348//MeanU Indoor: 0.013689965301021009
# Mean Outdoor: 4.096345514950166//STD Outdoor: 2.2175725108217588//MeanU Outdoor: 0.12803160860704565
#
# Difference is: 294.8542791556448

# %% [markdown]
# These results are clearly not even vaguely similar, there is far more particulate matter of all sizes outside compared to inside.
#
# We believe that we have reached the central limit theorem but the relationships are simply not gaussian, especially for indoors.

# %%
plt.hist(df4["PM2.5"],bins=8, label = "Indoor")
plt.hist(df3["PM2.5"],bins=8, label = "Outdoor")
plt.ylabel('Frequency')
plt.xlabel('PM 2.5')
plt.legend()
plt.show()

m4 = np.mean(df4["PM2.5"])
s4 = np.std(df4["PM2.5"])
u4 = s4/300**(1/2)

m3 = np.mean(df3["PM2.5"])
s3 = np.std(df3["PM2.5"])
u3 = s3/300**(1/2)

print("Mean Indoor: " + str(m4) + "//STD Indoor: " + str(s4) + "//MeanU Indoor: " + str(u4) + "\nMean Outdoor: " + str(m3) + "//STD Outdoor: " + str(s3) + "//MeanU Outdoor: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Indoor: 0.16943521594684385//STD Indoor: 0.3751358734430634//MeanU Indoor: 0.0216584797515038
# Mean Outdoor: 6.558139534883721//STD Outdoor: 3.4852477703022937//MeanU Outdoor: 0.20122087383765722
#
# Difference is: 294.9747347106989

# %% [markdown]
# These results are clearly not even vaguely similar, there is far more particulate matter of all sizes outside compared to inside.
# We believe that we have reached the central limit theorem but the relationships are simply not gaussian, especially for indoors.

# %%
plt.hist(df4["PM10"],bins=8, label = "Indoor")
plt.hist(df3["PM10"],bins=8, label = "Outdoor")
plt.ylabel('Frequency')
plt.xlabel('PM 10')
plt.legend()
plt.show()

m4 = np.mean(df4["PM10"])
s4 = np.std(df4["PM10"])
u4 = s4/300**(1/2)

m3 = np.mean(df3["PM10"])
s3 = np.std(df3["PM10"])
u3 = s3/300**(1/2)

print("Mean Indoor: " + str(m4) + "//STD Indoor: " + str(s4) + "//MeanU Indoor: " + str(u4) + "\nMean Outdoor: " + str(m3) + "//STD Outdoor: " + str(s3) + "//MeanU Outdoor: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Indoor: 0.16943521594684385//STD Indoor: 0.3751358734430634//MeanU Indoor: 0.0216584797515038
# Mean Outdoor: 6.857142857142857//STD Outdoor: 3.48363861732768//MeanU Outdoor: 0.20112796934735117
#
# Difference is: 308.78010450995157

# %% [markdown]
# These results are clearly not even vaguely similar, there is far more particulate matter of all sizes outside compared to inside.
#
# We believe that we have reached the central limit theorem but the relationships are simply not gaussian, especially for indoors.

# %%
plt.hist(df4["Temperature"],bins=40, label = "Indoor")
plt.hist(df3["Temperature"],bins=40, label = "Outdoor")
plt.ylabel('Frequency')
plt.xlabel('Temperature')
plt.legend()
plt.show()

m4 = np.mean(df4["Temperature"])
s4 = np.std(df4["Temperature"])
u4 = s4/300**(1/2)

m3 = np.mean(df3["Temperature"])
s3 = np.std(df3["Temperature"])
u3 = s3/300**(1/2)

print("Mean Indoor: " + str(m4) + "//STD Indoor: " + str(s4) + "//MeanU Indoor: " + str(u4) + "\nMean Outdoor: " + str(m3) + "//STD Outdoor: " + str(s3) + "//MeanU Outdoor: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Indoor: 22.84060073193519//STD Indoor: 0.27128303405359455//MeanU Indoor: 0.015662533273742122
# Mean Outdoor: 20.749144518272406//STD Outdoor: 1.666382882667881//MeanU Outdoor: 0.09620866058812856
#
# Difference is: 133.53243546936707

# %% [markdown]
# The temperature fluctuates wildly outside while staying extremely consistent inside.
#
# Because the data is so varied, it does not seem like we have reached central limit theorem, especially for outside.

# %%
plt.hist(df4["Gas"],bins=30, label = "Indoor")
plt.hist(df3["Gas"],bins=30, label = "Outdoor")
plt.ylabel('Frequency')
plt.xlabel('Gas')
plt.legend()
plt.show()

m4 = np.mean(df4["Gas"])
s4 = np.std(df4["Gas"])
u4 = s4/300**(1/2)

m3 = np.mean(df3["Gas"])
s3 = np.std(df3["Gas"])
u3 = s3/300**(1/2)

print("Mean Indoor: " + str(m4) + "//STD Indoor: " + str(s4) + "//MeanU Indoor: " + str(u4) + "\nMean Outdoor: " + str(m3) + "//STD Outdoor: " + str(s3) + "//MeanU Outdoor: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Indoor: 107208.81395348837//STD Indoor: 5389.389380282054//MeanU Indoor: 311.1565409473554
# Mean Outdoor: 104954.46511627907//STD Outdoor: 4645.2421902693295//MeanU Outdoor: 268.19318290030037
#
# Difference is: 7.245063305902708

# %% [markdown]
# These results are actually quite similar. They both are vaguely similar to a Gaussian model and have by far the smallest difference in means.
#
# This is close enough to the Gaussian that we don't need to comment much on central limit theorem, but more data could probably make it look more Gaussian.

# %%
plt.hist(df4["Humidity"],bins=20, label = "Indoor")
plt.hist(df3["Humidity"],bins=20, label = "Outdoor")
plt.ylabel('Frequency')
plt.xlabel('Humidity')
plt.legend()
plt.show()

m4 = np.mean(df4["Humidity"])
s4 = np.std(df4["Humidity"])
u4 = s4/300**(1/2)

m3 = np.mean(df3["Humidity"])
s3 = np.std(df3["Humidity"])
u3 = s3/300**(1/2)

print("Mean Indoor: " + str(m4) + "//STD Indoor: " + str(s4) + "//MeanU Indoor: " + str(u4) + "\nMean Outdoor: " + str(m3) + "//STD Outdoor: " + str(s3) + "//MeanU Outdoor: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Indoor: 26.74776895205221//STD Indoor: 0.6166359664336537//MeanU Indoor: 0.035601494121247496
# Mean Outdoor: 29.742749497856458//STD Outdoor: 2.121398871419196//MeanU Outdoor: 0.1224790209472441
#
# Difference is: 84.12513631041124

# %% [markdown]
# Indoor humidity is very consistent and low, but outside it fluctuates quite a bit and is higher because it is raining right now.
#
# The data is not very gaussian but it looks like it could be after a long time so we think that central limit theorem has not been reached yet.

# %%
plt.hist(df4["Pressure"],bins=20, label = "Indoor")
plt.hist(df3["Pressure"],bins=20, label = "Outdoor")
plt.ylabel('Frequency')
plt.xlabel('Pressure')
plt.legend()
plt.show()

m4 = np.mean(df4["Pressure"])
s4 = np.std(df4["Pressure"])
u4 = s4/300**(1/2)

m3 = np.mean(df3["Pressure"])
s3 = np.std(df3["Pressure"])
u3 = s3/300**(1/2)

print("Mean Indoor: " + str(m4) + "//STD Indoor: " + str(s4) + "//MeanU Indoor: " + str(u4) + "\nMean Outdoor: " + str(m3) + "//STD Outdoor: " + str(s3) + "//MeanU Outdoor: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Indoor: 996.2657296001357//STD Indoor: 0.02720068212663557//MeanU Indoor: 0.0015704321147954488
# Mean Outdoor: 995.7546027761088//STD Outdoor: 0.09945094986262173//MeanU Outdoor: 0.005741803267434863
#
# Difference is: 325.46890706800707

# %% [markdown]
# Pressure is fairly consistent for both indoor and outdoor measure, but it is slightly higher indoors possibly because we are deeper underground compared to when we air upstairs.
#
# The data is not very gaussian but it looks like it could be after a long time so we think that central limit theorem has not been reached yet.

# %%
plt.hist(df4["Altitude"],bins=20, label = "Indoor")
plt.hist(df3["Altitude"],bins=20, label = "Outdoor")
plt.ylabel('Frequency')
plt.xlabel('Altitude')
plt.legend()
plt.show()

m4 = np.mean(df4["Altitude"])
s4 = np.std(df4["Altitude"])
u4 = s4/300**(1/2)

m3 = np.mean(df3["Altitude"])
s3 = np.std(df3["Altitude"])
u3 = s3/300**(1/2)

print("Mean Indoor: " + str(m4) + "//STD Indoor: " + str(s4) + "//MeanU Indoor: " + str(u4) + "\nMean Outdoor: " + str(m3) + "//STD Outdoor: " + str(s3) + "//MeanU Outdoor: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Indoor: 142.37508654049282//STD Indoor: 0.22958569216385366//MeanU Indoor: 0.013255136117288745
# Mean Outdoor: 146.69014133607746//STD Outdoor: 0.839750675585399//MeanU Outdoor: 0.04848302786014001
#
# Difference is: 325.53832396760487

# %% [markdown]
# To get outdoors we go up some stairs, so these results are consistent with the fact that we are at a lower altitude inside.
#
# In reality our altitude is constant so the variation is simply based on mistakes being made by the computer, which should eventually become Gaussian by the central limit theorem if we took more data.

# %%
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
# Out:
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################

# %%
data_file = r"C:\Users\david\Documents\GitHub\E11_David_Julian_Matt\datainside-other_group.csv"
df4b = pd.read_csv(data_file)
display(df4b)

data_file = r"C:\Users\david\Documents\GitHub\E11_David_Julian_Matt\dataoutside-other_group.csv"
df3b = pd.read_csv(data_file)
display(df3b)
# Out:
#            time  Concentration Units (Standard) PM 1.0  \
# 0    1676677883                                      0
# 1    1676677885                                      0
# 2    1676677886                                      0
# 3    1676677887                                      1
# 4    1676677888                                      1
# ..          ...                                    ...
# 295  1676678235                                      0
# 296  1676678236                                      1
# 297  1676678237                                      0
# 298  1676678239                                      0
# 299  1676678240                                      0
#
#      Concentration Units (Standard) PM 2.5  \
# 0                                        2
# 1                                        2
# 2                                        2
# 3                                        2
# 4                                        2
# ...

# %%
plt.hist(df4b["Concentration Units (Standard) PM 1.0"],bins=8, label = "Theirs")
plt.hist(df4["PM 1.0"],bins=8, label = "Ours")
plt.ylabel('Frequency')
plt.xlabel('PM 1.0')
plt.legend()
plt.title("Indoors")
plt.show()

m4 = np.mean(df4b["Concentration Units (Standard) PM 1.0"])
s4 = np.std(df4b["Concentration Units (Standard) PM 1.0"])
u4 = s4/300**(1/2)

m3 = np.mean(df4["PM 1.0"])
s3 = np.std(df4["PM 1.0"])
u3 = s3/300**(1/2)

print("Mean Theirs: " + str(m4) + "//STD Theirs: " + str(s4) + "//MeanU Theirs: " + str(u4) + "\nMean Ours: " + str(m3) + "//STD Ours: " + str(s3) + "//MeanU Ours: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Theirs: 0.5//STD Theirs: 0.5//MeanU Theirs: 0.028867513459481284
# Mean Ours: 0.059800664451827246//STD Ours: 0.23711715455223348//MeanU Ours: 0.013689965301021009
#
# Difference is: 15.24895229254992

# %% [raw]
# Our results had very high consistency but were off by a count of 1 roughly.

# %%
plt.hist(df4b["Concentration Units (Standard) PM 2.5"],bins=8, label = "Theirs")
plt.hist(df4["PM2.5"],bins=8, label = "Ours")
plt.ylabel('Frequency')
plt.xlabel('PM 2.5')
plt.legend()
plt.title("Indoors")
plt.show()

m4 = np.mean(df4b["Concentration Units (Standard) PM 2.5"])
s4 = np.std(df4b["Concentration Units (Standard) PM 2.5"])
u4 = s4/300**(1/2)

m3 = np.mean(df4["PM2.5"])
s3 = np.std(df4["PM2.5"])
u3 = s3/300**(1/2)

print("Mean Thiers: " + str(m4) + "//STD Theirs: " + str(s4) + "//MeanU Theirs: " + str(u4) + "\nMean Ours: " + str(m3) + "//STD Ours: " + str(s3) + "//MeanU Ours: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Thiers: 1.0433333333333332//STD Theirs: 0.6283222810699047//MeanU Theirs: 0.036276203811354914
# Mean Ours: 0.16943521594684385//STD Ours: 0.3751358734430634//MeanU Ours: 0.0216584797515038
#
# Difference is: 24.090120397684725

# %% [markdown]
# In this one our results were less consistent, but nonetheless we typically counted 0 and they counted 1, which is a very small difference being consistently recorded.

# %%
plt.hist(df4b["Concentration Units (Standard) PM 10.0"],bins=8, label = "Theirs")
plt.hist(df4["PM10"],bins=8, label = "Ours")
plt.ylabel('Frequency')
plt.xlabel('PM 10.0')
plt.legend()
plt.title("Indoors")
plt.show()

m4 = np.mean(df4b["Concentration Units (Standard) PM 10.0"])
s4 = np.std(df4b["Concentration Units (Standard) PM 10.0"])
u4 = s4/300**(1/2)

m3 = np.mean(df4["PM10"])
s3 = np.std(df4["PM10"])
u3 = s3/300**(1/2)

print("Mean Theirs: " + str(m4) + "//STD Theirs: " + str(s4) + "//MeanU Theirs: " + str(u4) + "\nMean Ours: " + str(m3) + "//STD Ours: " + str(s3) + "//MeanU Ours: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Theirs: 1.2633333333333334//STD Theirs: 0.7707067463626432//MeanU Theirs: 0.044496774747873266
# Mean Ours: 0.16943521594684385//STD Ours: 0.3751358734430634//MeanU Ours: 0.0216584797515038
#
# Difference is: 24.583761937459812

# %% [markdown]
# In this one their results became less consistent but displayed a higher sensitivity to PM compared to our sensor, which was still conting 0 most of the time.

# %%
plt.hist(df4b["temperature"],bins=40, label = "Theirs")
plt.hist(df4["Temperature"],bins=40, label = "Ours")
plt.ylabel('Frequency')
plt.xlabel('Temperature')
plt.legend()
plt.title("Indoors")
plt.show()

m4 = np.mean(df4b["temperature"])
s4 = np.std(df4b["temperature"])
u4 = s4/300**(1/2)

m3 = np.mean(df4["Temperature"])
s3 = np.std(df4["Temperature"])
u3 = s3/300**(1/2)

print("Mean Theirs: " + str(m4) + "//STD Theirs: " + str(s4) + "//MeanU Theirs: " + str(u4) + "\nMean Ours: " + str(m3) + "//STD Ours: " + str(s3) + "//MeanU Ours: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Theirs: 22.680597656249976//STD Theirs: 0.10401821835210158//MeanU Theirs: 0.006005494636621111
# Mean Ours: 22.84060073193519//STD Ours: 0.27128303405359455//MeanU Ours: 0.015662533273742122
#
# Difference is: 26.64278054792123

# %% [markdown]
# Both of our data sets were very left-skewed, but ours was more skewed. Interestingly, we had the same mean even though the peaks seem far apart.

# %%
plt.hist(df4b["gas"],bins=30, label = "Theirs")
plt.hist(df4["Gas"],bins=30, label = "Ours")
plt.ylabel('Frequency')
plt.xlabel('Gas')
plt.legend()
plt.title("Indoors")
plt.show()

m4 = np.mean(df4b["gas"])
s4 = np.std(df4b["gas"])
u4 = s4/300**(1/2)

m3 = np.mean(df4["Gas"])
s3 = np.std(df4["Gas"])
u3 = s3/300**(1/2)

print("Mean Theirs: " + str(m4) + "//STD Theirs: " + str(s4) + "//MeanU Theirs: " + str(u4) + "\nMean Ours: " + str(m3) + "//STD Ours: " + str(s3) + "//MeanU Ours: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Theirs: 52721.30333333334//STD Theirs: 11416.647128848972//MeanU Theirs: 659.1404293083922
# Mean Ours: 107208.81395348837//STD Ours: 5389.389380282054//MeanU Ours: 311.1565409473554
#
# Difference is: 82.66449484418129

# %% [markdown]
# Theirs was extremely skewed left whereas this was our most Gaussian result. We recorded higher gases.

# %%
plt.hist(df4b["pressure"],bins=5, label = "Theirs")
plt.hist(df4["Pressure"],bins=5, label = "Ours")
plt.ylabel('Frequency')
plt.xlabel('Pressure')
plt.legend()
plt.title("Indoors")
plt.show()

m4 = np.mean(df4b["pressure"])
s4 = np.std(df4b["pressure"])
u4 = s4/300**(1/2)

m3 = np.mean(df4["Pressure"])
s3 = np.std(df4["Pressure"])
u3 = s3/300**(1/2)

print("Mean Theirs: " + str(m4) + "//STD Theirs: " + str(s4) + "//MeanU Theirs: " + str(u4) + "\nMean Ours: " + str(m3) + "//STD Ours: " + str(s3) + "//MeanU Ours: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Theirs: 1006.4574516136527//STD Theirs: 0.011946550127564032//MeanU Theirs: 0.0006897343932036451
# Mean Ours: 996.2657296001357//STD Ours: 0.02720068212663557//MeanU Ours: 0.0015704321147954488
#
# Difference is: 14776.299563921872

# %% [markdown]
# We both had extremely consistent pressure measurements, but for some reason were off by about 10 units.

# %%
plt.hist(df4b["altitude"],bins=5, label = "Theirs")
plt.hist(df4["Altitude"],bins=5, label = "Ours")
plt.ylabel('Frequency')
plt.xlabel('Altitude')
plt.legend()
plt.title("Indoors")
plt.show()

m4 = np.mean(df4b["altitude"])
s4 = np.std(df4b["altitude"])
u4 = s4/300**(1/2)

m3 = np.mean(df4["Altitude"])
s3 = np.std(df4["Altitude"])
u3 = s3/300**(1/2)

print("Mean Theirs: " + str(m4) + "//STD Theirs: " + str(s4) + "//MeanU Their: " + str(u4) + "\nMean Ours: " + str(m3) + "//STD Ours: " + str(s3) + "//MeanU Ours: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Theirs: 56.706717347805245//STD Theirs: 0.10000637187267354//MeanU Their: 0.0057738705721365885
# Mean Ours: 142.37508654049282//STD Ours: 0.22958569216385366//MeanU Ours: 0.013255136117288745
#
# Difference is: 14837.251393563274

# %% [markdown]
# We both had extremely consistent altitude measurements, but for some reason were off by about 80 units.

# %%
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
# Out:
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################

# %%
plt.hist(df3b["Concentration Units (Standard) PM 1.0"],bins=8, label = "Theirs")
plt.hist(df3["PM 1.0"],bins=8, label = "Ours")
plt.ylabel('Frequency')
plt.xlabel('PM 1.0')
plt.legend()
plt.title("Outdoors")
plt.show()

m4 = np.mean(df3b["Concentration Units (Standard) PM 1.0"])
s4 = np.std(df3b["Concentration Units (Standard) PM 1.0"])
u4 = s4/300**(1/2)

m3 = np.mean(df3["PM 1.0"])
s3 = np.std(df3["PM 1.0"])
u3 = s3/300**(1/2)

print("Mean Theirs: " + str(m4) + "//STD Theirs: " + str(s4) + "//MeanU Theirs: " + str(u4) + "\nMean Ours: " + str(m3) + "//STD Ours: " + str(s3) + "//MeanU Ours: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Theirs: 0.47//STD Theirs: 0.5499393905998498//MeanU Theirs: 0.031750765520080194
# Mean Ours: 4.096345514950166//STD Ours: 2.2175725108217588//MeanU Ours: 0.12803160860704565
#
# Difference is: 114.21285299898518

# %% [markdown]
# They had extremely consistently low values compared to our fairly even spread of high values while outside. They almost certainly measured in a different location.

# %%
plt.hist(df3b["Concentration Units (Standard) PM 2.5"],bins=8, label = "Theirs")
plt.hist(df3["PM2.5"],bins=8, label = "Ours")
plt.ylabel('Frequency')
plt.xlabel('PM 2.5')
plt.legend()
plt.title("Outdoors")
plt.show()

m4 = np.mean(df3b["Concentration Units (Standard) PM 2.5"])
s4 = np.std(df3b["Concentration Units (Standard) PM 2.5"])
u4 = s4/300**(1/2)

m3 = np.mean(df3["PM2.5"])
s3 = np.std(df3["PM2.5"])
u3 = s3/300**(1/2)

print("Mean Thiers: " + str(m4) + "//STD Theirs: " + str(s4) + "//MeanU Theirs: " + str(u4) + "\nMean Ours: " + str(m3) + "//STD Ours: " + str(s3) + "//MeanU Ours: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Thiers: 1.0333333333333334//STD Theirs: 0.8673074554171796//MeanU Theirs: 0.05007401928552779
# Mean Ours: 6.558139534883721//STD Ours: 3.4852477703022937//MeanU Ours: 0.20122087383765722
#
# Difference is: 110.33278894684507

# %% [markdown]
# They had extremely consistently low values compared to our fairly even spread of high values while outside, although we both had somewhat higher results for 2.5 compared to 1.0.

# %%
plt.hist(df3b["Concentration Units (Standard) PM 10.0"],bins=8, label = "Theirs")
plt.hist(df3["PM10"],bins=8, label = "Ours")
plt.ylabel('Frequency')
plt.xlabel('PM 10.0')
plt.legend()
plt.title("Outdoors")
plt.show()

m4 = np.mean(df3b["Concentration Units (Standard) PM 10.0"])
s4 = np.std(df3b["Concentration Units (Standard) PM 10.0"])
u4 = s4/300**(1/2)

m3 = np.mean(df3["PM10"])
s3 = np.std(df3["PM10"])
u3 = s3/300**(1/2)

print("Mean Theirs: " + str(m4) + "//STD Theirs: " + str(s4) + "//MeanU Theirs: " + str(u4) + "\nMean Ours: " + str(m3) + "//STD Ours: " + str(s3) + "//MeanU Ours: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Theirs: 1.2133333333333334//STD Theirs: 0.9279846742029513//MeanU Theirs: 0.053577220145492106
# Mean Ours: 6.857142857142857//STD Ours: 3.48363861732768//MeanU Ours: 0.20112796934735117
#
# Difference is: 105.33972289871376

# %% [markdown]
# They had extremely consistently low values compared to our fairly even spread of high values while outside. Our values did not increase much but theirs did by a decent amount.

# %%
plt.hist(df3b["temperature"],bins=40, label = "Theirs")
plt.hist(df3["Temperature"],bins=40, label = "Ours")
plt.ylabel('Frequency')
plt.xlabel('Temperature')
plt.legend()
plt.title("Outdoors")
plt.show()

m4 = np.mean(df3b["temperature"])
s4 = np.std(df3b["temperature"])
u4 = s4/300**(1/2)

m3 = np.mean(df3["Temperature"])
s3 = np.std(df3["Temperature"])
u3 = s3/300**(1/2)

print("Mean Theirs: " + str(m4) + "//STD Theirs: " + str(s4) + "//MeanU Theirs: " + str(u4) + "\nMean Ours: " + str(m3) + "//STD Ours: " + str(s3) + "//MeanU Ours: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Theirs: 14.089472656250011//STD Theirs: 2.51394780619259//MeanU Theirs: 0.14514284426339608
# Mean Ours: 20.749144518272406//STD Ours: 1.666382882667881//MeanU Ours: 0.09620866058812856
#
# Difference is: 45.883570050045606

# %% [markdown]
# We had overall higher temperature recording and both data sets were fairly spread out, although their standard deviation was slightly higher.

# %%
plt.hist(df3b["gas"],bins=30, label = "Theirs")
plt.hist(df3["Gas"],bins=30, label = "Ours")
plt.ylabel('Frequency')
plt.xlabel('Gas')
plt.legend()
plt.title("Outdoors")
plt.show()

m4 = np.mean(df3b["gas"])
s4 = np.std(df3b["gas"])
u4 = s4/300**(1/2)

m3 = np.mean(df3["Gas"])
s3 = np.std(df3["Gas"])
u3 = s3/300**(1/2)

print("Mean Theirs: " + str(m4) + "//STD Theirs: " + str(s4) + "//MeanU Theirs: " + str(u4) + "\nMean Ours: " + str(m3) + "//STD Ours: " + str(s3) + "//MeanU Ours: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Theirs: 61386.21666666667//STD Theirs: 23585.114853152376//MeanU Theirs: 1361.6872409335763
# Mean Ours: 104954.46511627907//STD Ours: 4645.2421902693295//MeanU Ours: 268.19318290030037
#
# Difference is: 31.995782247134738

# %% [markdown]
# Our gas measurements were extremely consistently very high but their range was quite gigantic. We are confused on how they measured 0 gas as our measurements are consistently in the 100000 range.

# %%
plt.hist(df3b["pressure"],bins=20, label = "Theirs")
plt.hist(df3["Pressure"],bins=5, label = "Ours")
plt.ylabel('Frequency')
plt.xlabel('Pressure')
plt.legend()
plt.title("Outdoors")
plt.show()

m4 = np.mean(df3b["pressure"])
s4 = np.std(df3b["pressure"])
u4 = s4/300**(1/2)

m3 = np.mean(df3["Pressure"])
s3 = np.std(df3["Pressure"])
u3 = s3/300**(1/2)

print("Mean Theirs: " + str(m4) + "//STD Theirs: " + str(s4) + "//MeanU Theirs: " + str(u4) + "\nMean Ours: " + str(m3) + "//STD Ours: " + str(s3) + "//MeanU Ours: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Theirs: 996.6479994733758//STD Theirs: 1.3089938992511172//MeanU Theirs: 0.07557479801002102
# Mean Ours: 995.7546027761088//STD Ours: 0.09945094986262173//MeanU Ours: 0.005741803267434863
#
# Difference is: 11.821357394148055

# %% [markdown]
# Their pressure measurements were extreely skewed right compared to ours, but they managed to have a very large amount of recordings within a very small range of each other at around the 997 unit level.

# %%
plt.hist(df3b["altitude"],bins=20, label = "Theirs")
plt.hist(df3["Altitude"],bins=10, label = "Ours")
plt.ylabel('Frequency')
plt.xlabel('Altitude')
plt.legend()
plt.title("Outdoors")
plt.show()

m4 = np.mean(df3b["altitude"])
s4 = np.std(df3b["altitude"])
u4 = s4/300**(1/2)

m3 = np.mean(df3["Altitude"])
s3 = np.std(df3["Altitude"])
u3 = s3/300**(1/2)

print("Mean Theirs: " + str(m4) + "//STD Theirs: " + str(s4) + "//MeanU Their: " + str(u4) + "\nMean Ours: " + str(m3) + "//STD Ours: " + str(s3) + "//MeanU Ours: " + str(u3))

dif = abs(m4-m3)/u4
print("\nDifference is: " + str(dif))
# Out:
# Mean Theirs: 139.15491085714726//STD Theirs: 11.010363841795824//MeanU Their: 0.635683652793654
# Mean Ours: 146.69014133607746//STD Ours: 0.839750675585399//MeanU Ours: 0.04848302786014001
#
# Difference is: 11.85374273164796

# %% [markdown]
# Very similar to our difference in pressure distributions, but this time they had an extremely left-skewed distribution. This makes sense since at higher altitudes there will be lower pressures.

# %%
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
print("#######################################################################################################################")
# Out:
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################
# #######################################################################################################################

# %% [markdown]
# We think its clear that our particulate matter sensor was far more sensitive than theirs because we detected far more PM than them. However, their atmospheric sensors were far more sensitive than ours as they were picking up a much larger range than us.

# %% [markdown]
# Extra Credit
# --------------------------------------------------------------------------------------------------------------

# %%
Data_file_file = df4
mask = Data_file_file["Time"] > 1677280869
data4 = Data_file_file[mask]
data4
# Out:
#              Time  PM 1.0  PM2.5  PM10  Temperature     Gas   Humidity  \
# 27   1.677281e+09       0      0     0    22.216328   90180  27.689746
# 28   1.677281e+09       0      0     0    22.221992   90735  27.658047
# 29   1.677281e+09       0      0     0    22.228242   91203  27.647820
# 30   1.677281e+09       0      0     0    22.233906   91866  27.632193
# 31   1.677281e+09       0      0     0    22.239961   91961  27.627307
# ..            ...     ...    ...   ...          ...     ...        ...
# 323  1.677281e+09       0      0     0    23.062031  115680  26.292801
# 324  1.677281e+09       0      0     0    23.059492  115454  26.255449
# 325  1.677281e+09       0      0     0    23.056172  115529  26.228663
# 326  1.677281e+09       0      0     0    23.054609  115756  26.202014
# 327  1.677281e+09       0      0     0    23.054023  115984  26.175443
#
#        Pressure    Altitude
# 27   996.299222  142.092396
# 28   996.296343  142.116700
# ...

# %%
plt.plot(data4["Humidity"],label = "Humidity")
plt.plot(data4["Temperature"],label = "Temperature")
plt.legend()
plt.ylabel("Humidity and Temperature")
plt.title("Temperature vs Humidity")
plt.show()

# %% [markdown]
# I believe the hidden variable when creating a plot like this is the x axis whenever making a non histogram plot, however this is simply the number of instances in which this result was collected, similar to frequency.

# %% [markdown]
# This graph shows us that on average the humidity will always be larger than temperature as well as temperature is roughly constant whereas humidity seems to fluctuate given the location, however this could just be a sensor error within the device. To quantify this we would say that temperatures ranging from roughly 22-23 degrees has a humidity of roughly 26-28 humidity.

# %%
plt.plot(data4["Temperature"], label = "Temperature")
plt.plot(data4["Altitude"], label = "Altitude")
plt.legend()
plt.ylabel("Temperature and Altitude")
plt.title("Temperature vs Altitude")
plt.show()

# %% [markdown]
# From the data there seems to be a overall correlation between altitude and temperature, whereas typically as altitude increases so does the temperature, although not inherently obvious we see a somewhat similar trend to that of temperautre and humidity, as much like humidity altitude is generally always larger than temperature.

# %%
plt.plot(data4["Temperature"], label = "Temperature")
plt.plot(data4["Gas"], label = "Gas")
plt.legend()
plt.ylabel("Temperature and Gas")
plt.title("Temperature vs Gas")
plt.show()

# %% [markdown]
# There seems to be a very weak relationship because temperature stays fairly constant throughout the chart.

# %%
plt.plot(data4["Temperature"], label = "Temperature")
plt.plot(data4["Pressure"], label = "Pressure")
plt.legend()
plt.ylabel("Temperature and Pressure")
plt.title("Temperature vs Pressure")
plt.show()

# %% [markdown]
# There seems to be little relation as both remain fairly constant over time.

# %%
plt.plot(data4["Temperature"], label = "Temperature")
plt.plot(data4["PM 1.0"], label = "PM 1.0")
plt.legend()
plt.ylabel("Temperature and PM 1.0")
plt.title("Temperature vs PM 1.0")
plt.show()

# %% [markdown]
# Both stay fairly constant over time and as such there does not seem to be a strong correlation.

# %%
plt.plot(data4["Temperature"], label = "Temperature")
plt.plot(data4["PM10"], label = "PM10")
plt.legend()
plt.ylabel("Temperature and PM 10")
plt.title("Temperature vs PM10")
plt.show()

# %% [markdown]
# There is a very weak correlation between temperature PM10 as seen by the chart.

# %%
plt.plot(data4["Temperature"], label = "Temperature")
plt.plot(data4["PM2.5"], label = "PM2.5")
plt.legend()
plt.ylabel("Temperature and PM2.5")
plt.title("Temperature vs PM2.5")
plt.show()

# %% [markdown]
# Overall I see no correlation between PM 2.5 and Temperature, however it seems that the concentration of particular matter is roughly always lower than temperature (hopefully), but overall no correlation I see both in term of numbers and the trends of the plot.
